# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- --------------------
# absl-py                      2.2.2
# aiofiles                     24.1.0
# aiogram                      3.20.0.post0
# aiohappyeyeballs             2.6.1
# aiohttp                      3.11.18
# aiosignal                    1.3.2
# annotated-types              0.7.0
# anyio                        4.9.0
# argon2-cffi                  23.1.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.3.0
# asttokens                    3.0.0
# astunparse                   1.6.3
# async-lru                    2.0.5
# async-timeout                5.0.1
# attrs                        25.3.0
# babel                        2.17.0
# beautifulsoup4               4.13.3
# bleach                       6.2.0
# cachetools                   5.5.2
# certifi                      2025.1.31
# cffi                         1.17.1
# charset-normalizer           3.4.1
# click                        8.1.8
# colorama                     0.4.6
# comm                         0.2.2
# config-reader                0.8
# contourpy                    1.3.0
# cycler                       0.12.1
# debugpy                      1.8.14
# decorator                    5.2.1
# defusedxml                   0.7.1
# exceptiongroup               1.2.2
# executing                    2.2.0
# fastjsonschema               2.21.1
# filelock                     3.18.0
# flatbuffers                  25.2.10
# fonttools                    4.57.0
# fqdn                         1.5.1
# frozenlist                   1.6.0
# future                       1.0.0
# gast                         0.4.0
# google-auth                  2.38.0
# google-auth-oauthlib         1.0.0
# google-pasta                 0.2.0
# grpcio                       1.70.0
# h11                          0.14.0
# h5py                         3.11.0
# httpcore                     1.0.7
# httpx                        0.28.1
# idna                         3.10
# importlib_metadata           8.5.0
# importlib_resources          6.5.2
# ipykernel                    6.29.5
# ipython                      8.18.1
# ipywidgets                   8.1.6
# isoduration                  20.11.0
# jedi                         0.19.2
# Jinja2                       3.1.6
# joblib                       1.4.2
# json5                        0.12.0
# jsonpointer                  3.0.0
# jsonschema                   4.23.0
# jsonschema-specifications    2024.10.1
# jupyter                      1.1.1
# jupyter_client               8.6.3
# jupyter-console              6.6.3
# jupyter_core                 5.7.2
# jupyter-events               0.12.0
# jupyter-lsp                  2.2.5
# jupyter_server               2.15.0
# jupyter_server_terminals     0.5.3
# jupyterlab                   4.4.0
# jupyterlab_pygments          0.3.0
# jupyterlab_server            2.27.3
# jupyterlab_widgets           3.0.14
# jupyterthemes                0.20.0
# keras                        3.9.2
# keras-nightly                3.10.0.dev2025050303
# kiwisolver                   1.4.7
# lesscpy                      0.15.1
# libclang                     18.1.1
# lightgbm                     4.6.0
# magic-filter                 1.0.12
# Markdown                     3.7
# markdown-it-py               3.0.0
# MarkupSafe                   2.1.5
# matplotlib                   3.9.4
# matplotlib-inline            0.1.7
# mdurl                        0.1.2
# mistune                      3.1.3
# ml_dtypes                    0.5.1
# multidict                    6.4.3
# namex                        0.0.9
# nbclient                     0.10.2
# nbconvert                    7.16.6
# nbformat                     5.10.4
# nest-asyncio                 1.6.0
# nltk                         3.9.1
# notebook                     7.4.0
# notebook_shim                0.2.4
# numpy                        2.0.2
# oauthlib                     3.2.2
# opt_einsum                   3.4.0
# optree                       0.15.0
# overrides                    7.7.0
# packaging                    24.2
# pandas                       2.2.3
# pandocfilters                1.5.1
# parso                        0.8.4
# pillow                       11.1.0
# pip                          23.2.1
# platformdirs                 4.3.7
# ply                          3.11
# prometheus_client            0.21.1
# prompt_toolkit               3.0.50
# propcache                    0.3.1
# protobuf                     4.25.6
# psutil                       7.0.0
# pure_eval                    0.2.3
# pyasn1                       0.6.1
# pyasn1_modules               0.4.2
# pycparser                    2.22
# pydantic                     2.11.3
# pydantic_core                2.33.1
# pydantic-settings            2.9.1
# Pygments                     2.19.1
# pyparsing                    3.2.3
# pyTelegramBotAPI             4.26.0
# python-dateutil              2.9.0.post0
# python-dotenv                1.1.0
# python-json-logger           3.3.0
# pytz                         2025.2
# pywin32                      310
# pywinpty                     2.0.15
# PyYAML                       6.0.2
# pyzmq                        26.4.0
# referencing                  0.36.2
# regex                        2024.11.6
# requests                     2.32.3
# requests-file                2.1.0
# requests-oauthlib            2.0.0
# rfc3339-validator            0.1.4
# rfc3986-validator            0.1.1
# rich                         14.0.0
# rpds-py                      0.24.0
# rsa                          4.9
# scikit-learn                 1.6.1
# scipy                        1.13.1
# seaborn                      0.13.2
# Send2Trash                   1.8.3
# setuptools                   68.2.0
# six                          1.17.0
# sniffio                      1.3.1
# soupsieve                    2.6
# stack-data                   0.6.3
# tensorboard                  2.19.0
# tensorboard-data-server      0.7.2
# tensorflow-estimator         2.13.0
# tensorflow-intel             2.13.0
# tensorflow-io-gcs-filesystem 0.31.0
# tensorflow_keras             0.1
# termcolor                    2.4.0
# terminado                    0.18.1
# threadpoolctl                3.6.0
# tinycss2                     1.4.0
# tldextract                   5.2.0
# tomli                        2.2.1
# tornado                      6.4.2
# tqdm                         4.67.1
# traitlets                    5.14.3
# types-python-dateutil        2.9.0.20241206
# typing_extensions            4.13.2
# typing-inspection            0.4.0
# tzdata                       2025.2
# uri-template                 1.3.0
# urllib3                      2.2.3
# wcwidth                      0.2.13
# webcolors                    24.11.1
# webencodings                 0.5.1
# websocket-client             1.8.0
# Werkzeug                     3.0.6
# wheel                        0.41.2
# widgetsnbextension           4.0.14
# wrapt                        1.17.2
# xgboost                      2.1.4
# yarl                         1.20.0
# zipp                         3.20.2
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import pickle

# 1. Загрузка данных
data = pd.read_csv("Malicious-URLs.csv") 
#Удаление дубликатов
data = data.drop_duplicates(subset="url").dropna()
data
# Out:
#        count                                                url       label
# 0          0                                   br-icloud.com.br    phishing
# 1          1                mp3raid.com/music/krizz_kaliko.html      benign
# 2          2                    bopsecrets.org/rexroth/cr/1.htm      benign
# 3          3  http://www.garage-pirenne.be/index.php?option=...  defacement
# 4          4  http://adventure-nicaragua.net/index.php?optio...  defacement
# ...      ...                                                ...         ...
# 14995  14995                               fortdefianceind.com/      benign
# 14996  14996   bookrags.com/lens/go.php?u=Hannah_Webster_Foster      benign
# 14997  14997       burbankairport.com/parking/buses-trains.html      benign
# 14998  14998  http://otomoto.pl/oferta/subaru-outback-legacy...      benign
# 14999  14999                    sfmuseum.org/hist2/bbridge.html      benign
#
# [14933 rows x 3 columns]

# %%
# 2. Преобразование меток
le = LabelEncoder()
data['label'] = le.fit_transform(data['label'])
data
# Out:
#        count                                                url  label
# 0          0                                   br-icloud.com.br      3
# 1          1                mp3raid.com/music/krizz_kaliko.html      0
# 2          2                    bopsecrets.org/rexroth/cr/1.htm      0
# 3          3  http://www.garage-pirenne.be/index.php?option=...      1
# 4          4  http://adventure-nicaragua.net/index.php?optio...      1
# ...      ...                                                ...    ...
# 14995  14995                               fortdefianceind.com/      0
# 14996  14996   bookrags.com/lens/go.php?u=Hannah_Webster_Foster      0
# 14997  14997       burbankairport.com/parking/buses-trains.html      0
# 14998  14998  http://otomoto.pl/oferta/subaru-outback-legacy...      0
# 14999  14999                    sfmuseum.org/hist2/bbridge.html      0
#
# [14933 rows x 3 columns]

# %%
# 3. Параметры токенизации
MAX_WORDS = 10000  # Максимальное количество токенов
MAX_LEN = 150      # Максимальная длина последовательности

# %%
# 4. Токенизация URL на уровне символов
tokenizer = Tokenizer(
    num_words=MAX_WORDS, 
    filters='', 
    lower=True, 
    char_level=True  # Токенизация по символам
)
tokenizer.fit_on_texts(data['url'])
data
# Out:
#        count                                                url  label
# 0          0                                   br-icloud.com.br      3
# 1          1                mp3raid.com/music/krizz_kaliko.html      0
# 2          2                    bopsecrets.org/rexroth/cr/1.htm      0
# 3          3  http://www.garage-pirenne.be/index.php?option=...      1
# 4          4  http://adventure-nicaragua.net/index.php?optio...      1
# ...      ...                                                ...    ...
# 14995  14995                               fortdefianceind.com/      0
# 14996  14996   bookrags.com/lens/go.php?u=Hannah_Webster_Foster      0
# 14997  14997       burbankairport.com/parking/buses-trains.html      0
# 14998  14998  http://otomoto.pl/oferta/subaru-outback-legacy...      0
# 14999  14999                    sfmuseum.org/hist2/bbridge.html      0
#
# [14933 rows x 3 columns]

# %%
# 5. Преобразование текста в последовательности
sequences = tokenizer.texts_to_sequences(data['url'])
X = pad_sequences(sequences, maxlen=MAX_LEN)
y = tf.keras.utils.to_categorical(data['label'])
data
# Out:
#        count                                                url  label
# 0          0                                   br-icloud.com.br      3
# 1          1                mp3raid.com/music/krizz_kaliko.html      0
# 2          2                    bopsecrets.org/rexroth/cr/1.htm      0
# 3          3  http://www.garage-pirenne.be/index.php?option=...      1
# 4          4  http://adventure-nicaragua.net/index.php?optio...      1
# ...      ...                                                ...    ...
# 14995  14995                               fortdefianceind.com/      0
# 14996  14996   bookrags.com/lens/go.php?u=Hannah_Webster_Foster      0
# 14997  14997       burbankairport.com/parking/buses-trains.html      0
# 14998  14998  http://otomoto.pl/oferta/subaru-outback-legacy...      0
# 14999  14999                    sfmuseum.org/hist2/bbridge.html      0
#
# [14933 rows x 3 columns]

# %%
# 6. Разделение данных
X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    test_size=0.2, 
    stratify=data['label'],
    random_state=42
)

# %%
# 7. Создание модели LSTM
model = Sequential()
model.add(Embedding(
    input_dim=MAX_WORDS, 
    output_dim=128, 
    input_length=MAX_LEN
))
model.add(LSTM(128, return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(64))
model.add(Dense(64, activation='relu'))
model.add(Dense(len(le.classes_), activation='softmax'))

model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)
# Out:
# C:\Python\projects\PythonProject\URL\.venv\lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
# 8. Обучение модели
from sklearn.utils.class_weight import compute_class_weight
history = model.fit(
    X_train, y_train,
    epochs=15,
    batch_size=128,
    validation_split=0.2,
    class_weight=dict(zip(  # Автовзвешивание классов
        range(len(le.classes_)), 
        compute_class_weight('balanced', classes=np.unique(data['label']), y=data['label'])
    ))
)
# Out:
# Epoch 1/15
# 75/75 [==============================] - 33s 405ms/step - loss: 1.1343 - accuracy: 0.3726 - val_loss: 1.0008 - val_accuracy: 0.6155
# Epoch 2/15
# 75/75 [==============================] - 30s 394ms/step - loss: 0.8373 - accuracy: 0.7063 - val_loss: 0.6329 - val_accuracy: 0.7808
# Epoch 3/15
# 75/75 [==============================] - 30s 401ms/step - loss: 0.6287 - accuracy: 0.7960 - val_loss: 0.4685 - val_accuracy: 0.8013
# Epoch 4/15
# 75/75 [==============================] - 33s 440ms/step - loss: 0.5304 - accuracy: 0.8739 - val_loss: 0.3083 - val_accuracy: 0.9025
# Epoch 5/15
# 75/75 [==============================] - 34s 459ms/step - loss: 0.4336 - accuracy: 0.9095 - val_loss: 0.3421 - val_accuracy: 0.8770
# Epoch 6/15
# 75/75 [==============================] - 33s 447ms/step - loss: 0.3942 - accuracy: 0.9048 - val_loss: 0.2996 - val_accuracy: 0.8979
# Epoch 7/15
# 75/75 [==============================] - 34s 448ms/step - loss: 0.3861 - accuracy: 0.8985 - val_loss: 0.2641 - val_accuracy: 0.8870
# Epoch 8/15
# 75/75 [==============================] - 35s 466ms/step - loss: 0.7086 - accuracy: 0.7460 - val_loss: 0.9732 - val_accuracy: 0.6908
# Epoch 9/15
# 75/75 [==============================] - 34s 457ms/step - loss: 0.6495 - accuracy: 0.7705 - val_loss: 0.2502 - val_accuracy: 0.9255
# Epoch 10/15
# 75/75 [==============================] - 34s 457ms/step - loss: 0.4322 - accuracy: 0.9024 - val_loss: 0.2685 - val_accuracy: 0.9096
# Epoch 11/15
# 75/75 [==============================] - 34s 460ms/step - loss: 0.3568 - accuracy: 0.9140 - val_loss: 0.4375 - val_accuracy: 0.8360
# Epoch 12/15
# 75/75 [==============================] - 35s 471ms/step - loss: 0.3359 - accuracy: 0.9160 - val_loss: 0.2347 - val_accuracy: 0.8992
# Epoch 13/15
# 75/75 [==============================] - 35s 464ms/step - loss: 0.2871 - accuracy: 0.9308 - val_loss: 0.2212 - val_accuracy: 0.9184
# Epoch 14/15
# 75/75 [==============================] - 34s 460ms/step - loss: 0.2776 - accuracy: 0.9266 - val_loss: 0.3353 - val_accuracy: 0.8803
# Epoch 15/15
# 75/75 [==============================] - 35s 468ms/step - loss: 0.6385 - accuracy: 0.7133 - val_loss: 0.4107 - val_accuracy: 0.8586

# %%
# 9. Оценка модели
y_pred = model.predict(X_test)
print(classification_report(
    np.argmax(y_test, axis=1), 
    np.argmax(y_pred, axis=1),
    target_names=le.classes_
))
# Out:
# 94/94 [==============================] - 2s 21ms/step
#               precision    recall  f1-score   support
#
#       benign       0.99      0.86      0.92      2199
#   defacement       0.72      0.83      0.77       545
#      malware       0.25      0.64      0.36        61
#     phishing       0.61      0.94      0.74       182
#
#     accuracy                           0.86      2987
#    macro avg       0.64      0.82      0.70      2987
# weighted avg       0.90      0.86      0.87      2987

# %%
# 10. Функция для предсказания
def predict_url_type(url):
    try:
        # Токенизация
        sequence = tokenizer.texts_to_sequences([url])
        padded = pad_sequences(sequence, maxlen=MAX_LEN)
        
        # Предсказание
        proba = model.predict(padded)[0]
        return {
            "url": url,
            "predicted_class": le.inverse_transform([np.argmax(proba)])[0],
            "probabilities": dict(zip(le.classes_, np.round(proba, 3)))
        }
    except Exception as e:
        return {"error": str(e)}

# Пример использования
print(predict_url_type("http://100linksdvgpn.avafedors.freedomain.thehost.com.ua"))
print(predict_url_type("https://kaggle.com"))
print(predict_url_type('https://web.telegram.org'))
# Out:
# 1/1 [==============================] - 0s 15ms/step
# {'url': 'http://100linksdvgpn.avafedors.freedomain.thehost.com.ua', 'predicted_class': 'phishing', 'probabilities': {'benign': 0.039, 'defacement': 0.093, 'malware': 0.342, 'phishing': 0.527}}
# 1/1 [==============================] - 0s 15ms/step
# {'url': 'https://kaggle.com', 'predicted_class': 'benign', 'probabilities': {'benign': 0.927, 'defacement': 0.063, 'malware': 0.006, 'phishing': 0.004}}
# 1/1 [==============================] - 0s 15ms/step
# {'url': 'https://web.telegram.org', 'predicted_class': 'benign', 'probabilities': {'benign': 0.851, 'defacement': 0.112, 'malware': 0.031, 'phishing': 0.006}}

# %%
model.save('url_classifier_LSTM.keras')
model.compiled_metrics == None
# Out:
# C:\Python\projects\PythonProject\URL\.venv\lib\site-packages\keras\src\saving\saving_api.py:107: UserWarning: You are saving a model that has not yet been built. It might not contain any weights yet. Consider building the model first by calling it on some data.
#   return saving_lib.save_model(model, filepath)
# False

# %%
from keras.models import load_model

m1 = load_model('url_classifier_LSTM.keras')

# %%
with open('tokenizer.pkl', 'wb') as out:
    pickle.dump(tokenizer, out)

# %%
with open('LabelEncoder.pkl', 'wb') as out:
    pickle.dump(le, out)
